# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tushare as ts
import datetime
import dateutil
import os
import pickle

#先引入后面可能用到的包（package）
# import talib as ta
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
# %matplotlib inline   
#正常显示画图时出现的中文和负号
from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

import datetime as dt

# %%
# find today's date
today = dt.date.today()
# delta = 1 day time delta
delta = dt.timedelta(days = 1)
# end_delta = 10 years ago
end_delta = dt.timedelta(days = 3652)

# Set the end of the sample to yesterday
end_of_sample = (today - delta)
# Set the start of the sample to 10 years ago
start_of_sample = (end_of_sample - end_delta)

# Change the data format from a 'datetime' element to a string which can be interpreted by Yahoo! Finance
end_of_sample = end_of_sample.isoformat()
start_of_sample = start_of_sample.isoformat()

# %%
# use Datreader to import S&P500 Data within the defined sample period
from pandas_datareader import data as pdr
dataset = pdr.get_data_yahoo("^GSPC", start=start_of_sample, end=end_of_sample).reset_index()

# %%
# define the conditions under which the algorithm should trigger a buy order or sell order
count = int(np.ceil(len(dataset) * 0.1))

action = pd.DataFrame(index=dataset.index)
action['trigger'] = 0.0
action['trend'] = dataset['Adj Close']

action['RollingMax'] = (action.trend.shift(1).rolling(count).max())
action['RollingMin'] = (action.trend.shift(1).rolling(count).min())

action.loc[action['RollingMax'] < action.trend, 'trigger'] = -1
action.loc[action['RollingMin'] > action.trend, 'trigger'] = 1

# %%
action
# Out:
#       trigger        trend   RollingMax  RollingMin
# 0         0.0  1385.300049          NaN         NaN
# 1         0.0  1379.319946          NaN         NaN
# 2         0.0  1375.319946          NaN         NaN
# 3         0.0  1365.000000          NaN         NaN
# 4         0.0  1390.989990          NaN         NaN
# ...       ...          ...          ...         ...
# 2512      0.0  3966.840088  4796.560059  3666.77002
# 2513      0.0  3921.050049  4796.560059  3666.77002
# 2514      0.0  4023.610107  4796.560059  3666.77002
# 2515      0.0  4072.429932  4796.560059  3666.77002
# 2516      0.0  4130.290039  4796.560059  3666.77002
#
# [2517 rows x 4 columns]

# %%
# this executable is a decision function for the algorithm
def trade(price_change, trigger, capital = 10_000, maximum_long = 1, maximum_short = 1,):
    """
    price_change = S&P500 price change (Absolute Value)
    trigger = 1 initiates a buy order, -1 initiates sell order
    capital = The initial capital committed to algorithm (the _ acts as a comma for large values)
    maximum_long = the maximum quantity that can be purchased in any one action
    maximum_short = maximum quantity that can be sold in any one action (note the shortselling restriction)
    """
    starting_capital = capital
    sell_states = []
    buy_states = []
    inventory = 0

    def buy(i, capital, inventory):
        shares = capital // price_change[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough capital to buy a unit price %f'
                % (i, capital, price_change[i])
            )
        else:
            if shares > maximum_long:
                buy_units = maximum_long
            else:
                buy_units = shares
            capital -= buy_units * price_change[i]
            inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * price_change[i], capital)
            )
            buy_states.append(0)
        return capital, inventory

    for i in range(price_change.shape[0] - int(0.025 * len(dataset))):
        state = trigger[i]
        if state == 1:
            capital, inventory = buy( i, capital, inventory)
            buy_states.append(i)
        elif state == -1:
            if inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
            else:
                if inventory > maximum_short:
                    sell_units = maximum_short
                else:
                    sell_units = inventory
                inventory -= sell_units
                total_sell = sell_units * price_change[i]
                capital += total_sell
                try:
                    invest = (
                        (price_change[i] - price_change[buy_states[-1]])
                        / price_change[buy_states[-1]]) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (i, sell_units, total_sell, invest, capital))
            sell_states.append(i)
            
    invest = ((capital - starting_capital) / starting_capital) * 100
    total_gains = capital - starting_capital
    return buy_states, sell_states, total_gains, invest

# %%
# we must pass arguments to the decision function
buy_states, sell_states, total_gains, invest = trade(dataset['Adj Close'], action['trigger'])


# Let's define a quick function which generates the Index returns, to allow benchmarking
def Index_Returns(start_value, end_value):
    return (((end_value - start_value) / start_value) -1) * 100

# We can pass this function the required arguments to calculate a simple return
SP_500_Returns = Index_Returns(dataset['Adj Close'].iloc[0], dataset['Adj Close'].iloc[-1])
# Out:
# day 252: cannot sell anything, inventory 0
# day 253: cannot sell anything, inventory 0
# day 285: cannot sell anything, inventory 0
# day 306: cannot sell anything, inventory 0
# day 307: cannot sell anything, inventory 0
# day 308: cannot sell anything, inventory 0
# day 309: cannot sell anything, inventory 0
# day 312: cannot sell anything, inventory 0
# day 313: cannot sell anything, inventory 0
# day 314: cannot sell anything, inventory 0
# day 325: cannot sell anything, inventory 0
# day 326: cannot sell anything, inventory 0
# day 327: cannot sell anything, inventory 0
# day 332: cannot sell anything, inventory 0
# day 335: cannot sell anything, inventory 0
# day 342: cannot sell anything, inventory 0
# day 349: cannot sell anything, inventory 0
# day 351: cannot sell anything, inventory 0
# day 352: cannot sell anything, inventory 0
# day 353: cannot sell anything, inventory 0
# day 354: cannot sell anything, inventory 0
# day 357: cannot sell anything, inventory 0
# day 367: cannot sell anything, inventory 0
# day 396: cannot sell anything, inventory 0
# day 397: cannot sell anything, inventory 0
# day 399: cannot sell anything, inventory 0
# day 401: cannot sell anything, inventory 0
# day 402: cannot sell anything, inventory 0
# day 419: cannot sell anything, inventory 0
# day 420: cannot sell anything, inventory 0
# day 447: cannot sell anything, inventory 0
# day 448: cannot sell anything, inventory 0
# day 456: cannot sell anything, inventory 0
# day 457: cannot sell anything, inventory 0
# day 459: cannot sell anything, inventory 0
# day 460: cannot sell anything, inventory 0
# day 461: cannot sell anything, inventory 0
# day 463: cannot sell anything, inventory 0
# day 464: cannot sell anything, inventory 0
# day 465: cannot sell anything, inventory 0
# day 466: cannot sell anything, inventory 0
# day 473: cannot sell anything, inventory 0
# day 474: cannot sell anything, inventory 0
# day 475: cannot sell anything, inventory 0
# day 482: cannot sell anything, inventory 0
# day 483: cannot sell anything, inventory 0
# day 484: cannot sell anything, inventory 0
# day 497: cannot sell anything, inventory 0
# day 498: cannot sell anything, inventory 0
# day 518: cannot sell anything, inventory 0
# day 520: cannot sell anything, inventory 0
# day 521: cannot sell anything, inventory 0
# day 522: cannot sell anything, inventory 0
# day 524: cannot sell anything, inventory 0
# day 528: cannot sell anything, inventory 0
# day 537: cannot sell anything, inventory 0
# day 568: cannot sell anything, inventory 0
# day 571: cannot sell anything, inventory 0
# day 572: cannot sell anything, inventory 0
# day 573: cannot sell anything, inventory 0
# day 574: cannot sell anything, inventory 0
# day 575: cannot sell anything, inventory 0
# day 578: cannot sell anything, inventory 0
# day 579: cannot sell anything, inventory 0
# day 580: cannot sell anything, inventory 0
# day 582: cannot sell anything, inventory 0
# day 583: cannot sell anything, inventory 0
# day 584: cannot sell anything, inventory 0
# day 586: cannot sell anything, inventory 0
# day 590: cannot sell anything, inventory 0
# day 592: cannot sell anything, inventory 0
# day 603: cannot sell anything, inventory 0
# day 604: cannot sell anything, inventory 0
# day 606: cannot sell anything, inventory 0
# day 607: cannot sell anything, inventory 0
# day 639: cannot sell anything, inventory 0
# day 640: cannot sell anything, inventory 0
# day 643: cannot sell anything, inventory 0
# day 645: cannot sell anything, inventory 0
# day 649: cannot sell anything, inventory 0
# day 687: cannot sell anything, inventory 0
# day 701: cannot sell anything, inventory 0
# day 702: cannot sell anything, inventory 0
# day 703: cannot sell anything, inventory 0
# day 706: cannot sell anything, inventory 0
# day 873: buy 1 units at price 1859.329956, total balance 8140.670044
# day 873: buy 1 units at price 1859.329956, total balance 8140.670044
# day 873: buy 1 units at price 1859.329956, total balance 8140.670044
# day 873: buy 1 units at price 1859.329956, total balance 8140.670044
# day 873: buy 1 units at price 1859.329956, total balance 8140.670044
# day 886: buy 1 units at price 1853.439941, total balance 6287.230103
# day 887: buy 1 units at price 1852.209961, total balance 4435.020142
# day 888: buy 1 units at price 1851.859985, total balance 2583.160156
# day 889: buy 1 units at price 1829.079956, total balance 754.080200
# day 991, sell 1 units at price 2129.899902, investment 16.446517 %, total balance 2883.980103,
# day 991, sell 1 units at price 2129.899902, investment 16.446517 %, total balance 2883.980103,
# day 991, sell 1 units at price 2129.899902, investment 16.446517 %, total balance 2883.980103,
# day 991, sell 1 units at price 2129.899902, investment 16.446517 %, total balance 2883.980103,
# day 991, sell 1 units at price 2129.899902, investment 16.446517 %, total balance 2883.980103,
# day 992, sell 1 units at price 2137.159912, investment 16.843438 %, total balance 5021.140015,
# day 993, sell 1 units at price 2152.139893, investment 17.662428 %, total balance 7173.279907,
# day 994, sell 1 units at price 2152.429932, investment 17.678285 %, total balance 9325.709839,
# day 995, sell 1 units at price 2163.750000, investment 18.297180 %, total balance 11489.459839,
# day 997: cannot sell anything, inventory 0
# day 999: cannot sell anything, inventory 0
# day 1001: cannot sell anything, inventory 0
# day 1011: cannot sell anything, inventory 0
# day 1015: cannot sell anything, inventory 0
# day 1017: cannot sell anything, inventory 0
# day 1086: cannot sell anything, inventory 0
# day 1087: cannot sell anything, inventory 0
# day 1088: cannot sell anything, inventory 0
# day 1089: cannot sell anything, inventory 0
# day 1097: cannot sell anything, inventory 0
# day 1098: cannot sell anything, inventory 0
# day 1099: cannot sell anything, inventory 0
# day 1101: cannot sell anything, inventory 0
# day 1117: cannot sell anything, inventory 0
# day 1128: cannot sell anything, inventory 0
# day 1129: cannot sell anything, inventory 0
# day 1140: cannot sell anything, inventory 0
# day 1141: cannot sell anything, inventory 0
# day 1142: cannot sell anything, inventory 0
# day 1143: cannot sell anything, inventory 0
# day 1144: cannot sell anything, inventory 0
# day 1146: cannot sell anything, inventory 0
# day 1147: cannot sell anything, inventory 0
# day 1150: cannot sell anything, inventory 0
# day 1151: cannot sell anything, inventory 0
# day 1153: cannot sell anything, inventory 0
# day 1199: cannot sell anything, inventory 0
# day 1200: cannot sell anything, inventory 0
# day 1202: cannot sell anything, inventory 0
# day 1205: cannot sell anything, inventory 0
# day 1212: cannot sell anything, inventory 0
# day 1213: cannot sell anything, inventory 0
# day 1214: cannot sell anything, inventory 0
# day 1217: cannot sell anything, inventory 0
# day 1218: cannot sell anything, inventory 0
# day 1225: cannot sell anything, inventory 0
# day 1229: cannot sell anything, inventory 0
# day 1247: cannot sell anything, inventory 0
# day 1249: cannot sell anything, inventory 0
# day 1250: cannot sell anything, inventory 0
# day 1254: cannot sell anything, inventory 0
# day 1255: cannot sell anything, inventory 0
# day 1263: cannot sell anything, inventory 0
# day 1287: cannot sell anything, inventory 0
# day 1288: cannot sell anything, inventory 0
# day 1289: cannot sell anything, inventory 0
# day 1291: cannot sell anything, inventory 0
# day 1292: cannot sell anything, inventory 0
# day 1293: cannot sell anything, inventory 0
# day 1294: cannot sell anything, inventory 0
# day 1300: cannot sell anything, inventory 0
# day 1301: cannot sell anything, inventory 0
# day 1302: cannot sell anything, inventory 0
# day 1303: cannot sell anything, inventory 0
# day 1304: cannot sell anything, inventory 0
# day 1305: cannot sell anything, inventory 0
# day 1309: cannot sell anything, inventory 0
# day 1312: cannot sell anything, inventory 0
# day 1313: cannot sell anything, inventory 0
# day 1314: cannot sell anything, inventory 0
# day 1315: cannot sell anything, inventory 0
# day 1316: cannot sell anything, inventory 0
# day 1321: cannot sell anything, inventory 0
# day 1326: cannot sell anything, inventory 0
# day 1327: cannot sell anything, inventory 0
# day 1329: cannot sell anything, inventory 0
# day 1338: cannot sell anything, inventory 0
# day 1340: cannot sell anything, inventory 0
# day 1342: cannot sell anything, inventory 0
# day 1344: cannot sell anything, inventory 0
# day 1350: cannot sell anything, inventory 0
# day 1351: cannot sell anything, inventory 0
# day 1352: cannot sell anything, inventory 0
# day 1355: cannot sell anything, inventory 0
# day 1356: cannot sell anything, inventory 0
# day 1365: cannot sell anything, inventory 0
# day 1366: cannot sell anything, inventory 0
# day 1367: cannot sell anything, inventory 0
# day 1368: cannot sell anything, inventory 0
# day 1369: cannot sell anything, inventory 0
# day 1370: cannot sell anything, inventory 0
# day 1372: cannot sell anything, inventory 0
# day 1373: cannot sell anything, inventory 0
# day 1375: cannot sell anything, inventory 0
# day 1377: cannot sell anything, inventory 0
# day 1378: cannot sell anything, inventory 0
# day 1379: cannot sell anything, inventory 0
# day 1381: cannot sell anything, inventory 0
# day 1382: cannot sell anything, inventory 0
# day 1528: cannot sell anything, inventory 0
# day 1529: cannot sell anything, inventory 0
# day 1530: cannot sell anything, inventory 0
# day 1531: cannot sell anything, inventory 0
# day 1546: cannot sell anything, inventory 0
# day 1606: buy 1 units at price 2545.939941, total balance 8943.519897
# day 1608: buy 1 units at price 2506.959961, total balance 6436.559937
# day 1609: buy 1 units at price 2467.419922, total balance 3969.140015
# day 1610: buy 1 units at price 2416.620117, total balance 1552.519897
# day 1611: total balances 1552.519897, not enough capital to buy a unit price 2351.100098
# day 1692, sell 1 units at price 2933.679932, investment 24.779032 %, total balance 4486.199829,
# day 1695, sell 1 units at price 2939.879883, investment 25.042736 %, total balance 7426.079712,
# day 1696, sell 1 units at price 2943.030029, investment 25.176722 %, total balance 10369.109741,
# day 1697, sell 1 units at price 2945.830078, investment 25.295817 %, total balance 13314.939819,
# day 1733: cannot sell anything, inventory 0
# day 1740: cannot sell anything, inventory 0
# day 1741: cannot sell anything, inventory 0
# day 1742: cannot sell anything, inventory 0
# day 1747: cannot sell anything, inventory 0
# day 1748: cannot sell anything, inventory 0
# day 1749: cannot sell anything, inventory 0
# day 1756: cannot sell anything, inventory 0
# day 1758: cannot sell anything, inventory 0
# day 1823: cannot sell anything, inventory 0
# day 1825: cannot sell anything, inventory 0
# day 1827: cannot sell anything, inventory 0
# day 1828: cannot sell anything, inventory 0
# day 1831: cannot sell anything, inventory 0
# day 1832: cannot sell anything, inventory 0
# day 1835: cannot sell anything, inventory 0
# day 1836: cannot sell anything, inventory 0
# day 1837: cannot sell anything, inventory 0
# day 1838: cannot sell anything, inventory 0
# day 1843: cannot sell anything, inventory 0
# day 1844: cannot sell anything, inventory 0
# day 1845: cannot sell anything, inventory 0
# day 1855: cannot sell anything, inventory 0
# day 1856: cannot sell anything, inventory 0
# day 1857: cannot sell anything, inventory 0
# day 1858: cannot sell anything, inventory 0
# day 1860: cannot sell anything, inventory 0
# day 1861: cannot sell anything, inventory 0
# day 1862: cannot sell anything, inventory 0
# day 1864: cannot sell anything, inventory 0
# day 1865: cannot sell anything, inventory 0
# day 1868: cannot sell anything, inventory 0
# day 1873: cannot sell anything, inventory 0
# day 1875: cannot sell anything, inventory 0
# day 1877: cannot sell anything, inventory 0
# day 1878: cannot sell anything, inventory 0
# day 1879: cannot sell anything, inventory 0
# day 1891: cannot sell anything, inventory 0
# day 1892: cannot sell anything, inventory 0
# day 1894: cannot sell anything, inventory 0
# day 1895: cannot sell anything, inventory 0
# day 1896: cannot sell anything, inventory 0
# day 1898: cannot sell anything, inventory 0
# day 1900: cannot sell anything, inventory 0
# day 1915: buy 1 units at price 2741.379883, total balance 10573.559937
# day 1916: buy 1 units at price 2480.639893, total balance 8092.920044
# day 1918: buy 1 units at price 2386.129883, total balance 5706.790161
# day 1922: buy 1 units at price 2304.919922, total balance 3401.870239
# day 1923: buy 1 units at price 2237.399902, total balance 1164.470337
# day 2026, sell 1 units at price 3389.780029, investment 51.505327 %, total balance 4554.250366,
# day 2029, sell 1 units at price 3397.159912, investment 51.835169 %, total balance 7951.410278,
# day 2030, sell 1 units at price 3431.280029, investment 53.360158 %, total balance 11382.690308,
# day 2031, sell 1 units at price 3443.620117, investment 53.911695 %, total balance 14826.310425,
# day 2032, sell 1 units at price 3478.729980, investment 55.480921 %, total balance 18305.040405,
# day 2033: cannot sell anything, inventory 0
# day 2034: cannot sell anything, inventory 0
# day 2036: cannot sell anything, inventory 0
# day 2037: cannot sell anything, inventory 0
# day 2088: cannot sell anything, inventory 0
# day 2089: cannot sell anything, inventory 0
# day 2095: cannot sell anything, inventory 0
# day 2097: cannot sell anything, inventory 0
# day 2099: cannot sell anything, inventory 0
# day 2100: cannot sell anything, inventory 0
# day 2102: cannot sell anything, inventory 0
# day 2104: cannot sell anything, inventory 0
# day 2111: cannot sell anything, inventory 0
# day 2117: cannot sell anything, inventory 0
# day 2120: cannot sell anything, inventory 0
# day 2124: cannot sell anything, inventory 0
# day 2125: cannot sell anything, inventory 0
# day 2132: cannot sell anything, inventory 0
# day 2133: cannot sell anything, inventory 0
# day 2135: cannot sell anything, inventory 0
# day 2143: cannot sell anything, inventory 0
# day 2144: cannot sell anything, inventory 0
# day 2145: cannot sell anything, inventory 0
# day 2148: cannot sell anything, inventory 0
# day 2149: cannot sell anything, inventory 0
# day 2167: cannot sell anything, inventory 0
# day 2168: cannot sell anything, inventory 0
# day 2169: cannot sell anything, inventory 0
# day 2171: cannot sell anything, inventory 0
# day 2178: cannot sell anything, inventory 0
# day 2182: cannot sell anything, inventory 0
# day 2183: cannot sell anything, inventory 0
# day 2185: cannot sell anything, inventory 0
# day 2186: cannot sell anything, inventory 0
# day 2187: cannot sell anything, inventory 0
# day 2189: cannot sell anything, inventory 0
# day 2191: cannot sell anything, inventory 0
# day 2192: cannot sell anything, inventory 0
# day 2198: cannot sell anything, inventory 0
# day 2201: cannot sell anything, inventory 0
# day 2207: cannot sell anything, inventory 0
# day 2230: cannot sell anything, inventory 0
# day 2231: cannot sell anything, inventory 0
# day 2232: cannot sell anything, inventory 0
# day 2240: cannot sell anything, inventory 0
# day 2241: cannot sell anything, inventory 0
# day 2242: cannot sell anything, inventory 0
# day 2243: cannot sell anything, inventory 0
# day 2244: cannot sell anything, inventory 0
# day 2245: cannot sell anything, inventory 0
# day 2246: cannot sell anything, inventory 0
# day 2248: cannot sell anything, inventory 0
# day 2250: cannot sell anything, inventory 0
# day 2251: cannot sell anything, inventory 0
# day 2260: cannot sell anything, inventory 0
# day 2261: cannot sell anything, inventory 0
# day 2267: cannot sell anything, inventory 0
# day 2269: cannot sell anything, inventory 0
# day 2270: cannot sell anything, inventory 0
# day 2272: cannot sell anything, inventory 0
# day 2273: cannot sell anything, inventory 0
# day 2274: cannot sell anything, inventory 0
# day 2275: cannot sell anything, inventory 0
# day 2276: cannot sell anything, inventory 0
# day 2282: cannot sell anything, inventory 0
# day 2283: cannot sell anything, inventory 0
# day 2285: cannot sell anything, inventory 0
# day 2286: cannot sell anything, inventory 0
# day 2289: cannot sell anything, inventory 0
# day 2323: cannot sell anything, inventory 0
# day 2325: cannot sell anything, inventory 0
# day 2326: cannot sell anything, inventory 0
# day 2328: cannot sell anything, inventory 0
# day 2329: cannot sell anything, inventory 0
# day 2330: cannot sell anything, inventory 0
# day 2331: cannot sell anything, inventory 0
# day 2332: cannot sell anything, inventory 0
# day 2333: cannot sell anything, inventory 0
# day 2334: cannot sell anything, inventory 0
# day 2335: cannot sell anything, inventory 0
# day 2343: cannot sell anything, inventory 0
# day 2358: cannot sell anything, inventory 0
# day 2367: cannot sell anything, inventory 0
# day 2368: cannot sell anything, inventory 0
# day 2370: cannot sell anything, inventory 0
# day 2373: cannot sell anything, inventory 0

# %%
# Plot the S&P500 Closing Price
value = dataset['Adj Close']
fig = plt.figure(figsize = (15,5))
plt.plot(value, color='b', lw=2.)

# Plot the Entry and Exit Signals generated by the algorithm
plt.plot(value, '^', markersize=8, color='g', label = 'Trigger Entry', markevery = buy_states)
plt.plot(value, 'v', markersize=8, color='r', label = 'Trigger Exit', markevery = sell_states)

# Chart Title displaying the Absolute Returns, Return on Capital & Benchmark Returns
plt.title('Absolute Returns: $%f, Return on Capital: %f%%, Benchmark Return: %f%%'%(round(total_gains,2), round(invest,2), round(SP_500_Returns,2)))
plt.legend()
plt.show();
